# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# add repository root to path
repo_root_path = !(git rev-parse --show-toplevel)
sys.path.append(repo_root_path[0])

print(f"✅ Addded to path: {repo_root_path[0]}")
